# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from datetime import datetime
import missingno as msno
file_path = "netflix_titles.csv"
df = pd.read_csv(file_path)
df.head()
df.tail()
#df.info()
dimensions = df.shape
#print(dimensions)
colonnes = len(df.columns)
type_colonnes = df.dtypes
print(type_colonnes)
total_valeurs_manquantes=df.isnull().sum().sum()
total_valeurs=df.size
pourcentage_manquantes = (total_valeurs_manquantes / total_valeurs )* 100
#print(pourcentage_manquantes)
#msno.matrix(df)
échantillon_aléatoire = df.sample(n=1)
#print(échantillon_aléatoire)
catch_me_if_you_can=df[df['title'] == 'Catch Me If You Can']
#print(catch_me_if_you_can)
df['date_added'] = df['date_added'].str.strip()
df['date_added'] = pd.to_datetime(df['date_added'],format='%B %d, %Y')

df_series = df[df['type'] == 'TV Show']
dernier_ajout_index_series = df_series['date_added'].idxmax()
dernier_ajout_series = df_series.loc[dernier_ajout_index_series]
print(dernier_ajout_index_series)

dernier_ajout_index = df['date_added'].idxmax()
dernier_ajout = df.loc[dernier_ajout_index]
print(dernier_ajout)
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object
# 1
# show_id                                                        s1
# type                                                        Movie
# title                                        Dick Johnson Is Dead
# director                                          Kirsten Johnson
# cast                                                          NaN
# country                                             United States
# date_added                                    2021-09-25 00:00:00
# release_year                                                 2020
# rating                                                      PG-13
# duration                                                   90 min
# ...
